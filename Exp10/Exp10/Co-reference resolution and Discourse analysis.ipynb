# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm


import spacy
import string

# ---------------------------------------------
# Load spaCy model
# ---------------------------------------------
nlp = spacy.load("en_core_web_sm")

# ---------------------------------------------
# Simple Co-reference Resolution
# ---------------------------------------------
def resolve_coreference(text):

    doc = nlp(text)

    print("\n===== CO-REFERENCE RESOLUTION =====")

    last_noun = None

    for token in doc:

        if token.pos_ in ["PROPN", "NOUN"]:
            last_noun = token.text
            print(token.text, "--> Noun/Noun Phrase")

        elif token.pos_ == "PRON":
            if last_noun:
                print(token.text, "--> refers to", last_noun)
            else:
                print(token.text, "--> Pronoun")


# ---------------------------------------------
# Discourse Analysis
# ---------------------------------------------
def discourse_analysis(text):

    discourse_markers = {
        "because": "Cause",
        "therefore": "Result",
        "thus": "Result",
        "however": "Contrast",
        "although": "Contrast",
        "but": "Contrast",
        "then": "Sequence",
        "finally": "Conclusion",
        "after": "Temporal",
        "before": "Temporal"
    }

    words = text.lower().split()
    found = []

    for w in words:
        w = w.strip(string.punctuation)

        if w in discourse_markers:
            found.append((w, discourse_markers[w]))

    print("\n===== DISCOURSE RELATIONS =====")

    if len(found) == 0:
        print("No discourse markers detected")
    else:
        for marker, relation in found:
            print(marker, "-->", relation)


# ---------------------------------------------
# Main
# ---------------------------------------------
paragraph = input("Enter paragraph:\n")

resolve_coreference(paragraph)
discourse_analysis(paragraph)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 74.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Enter paragraph:
# John went to school because he had an exam. However, he was late.
#
# ===== CO-REFERENCE RESOLUTION =====
# John --> Noun/Noun Phrase
# school --> Noun/Noun Phrase
# he --> refers to school
# exam --> Noun/Noun Phrase
# he --> refers to exam
#
# ===== DISCOURSE RELATIONS =====
# because --> Cause
# however --> Contrast

# %%
import spacy
import string

# ---------------------------------------------
# Load spaCy model
# ---------------------------------------------
nlp = spacy.load("en_core_web_sm")

# ---------------------------------------------
# Simple Co-reference Resolution
# ---------------------------------------------
def resolve_coreference(text):

    doc = nlp(text)

    print("\n===== CO-REFERENCE RESOLUTION =====")

    last_noun = None

    for token in doc:

        if token.pos_ in ["PROPN", "NOUN"]:
            last_noun = token.text
            print(token.text, "--> Noun/Noun Phrase")

        elif token.pos_ == "PRON":
            if last_noun:
                print(token.text, "--> refers to", last_noun)
            else:
                print(token.text, "--> Pronoun")


# ---------------------------------------------
# Discourse Analysis
# ---------------------------------------------
def discourse_analysis(text):

    discourse_markers = {
        "because": "Cause",
        "therefore": "Result",
        "thus": "Result",
        "however": "Contrast",
        "although": "Contrast",
        "but": "Contrast",
        "then": "Sequence",
        "finally": "Conclusion",
        "after": "Temporal",
        "before": "Temporal"
    }

    words = text.lower().split()
    found = []

    for w in words:
        w = w.strip(string.punctuation)

        if w in discourse_markers:
            found.append((w, discourse_markers[w]))

    print("\n===== DISCOURSE RELATIONS =====")

    if len(found) == 0:
        print("No discourse markers detected")
    else:
        for marker, relation in found:
            print(marker, "-->", relation)


# ---------------------------------------------
# Main
# ---------------------------------------------
paragraph = input("Enter paragraph:\n")

resolve_coreference(paragraph)
discourse_analysis(paragraph)
# Out:
# Enter paragraph:
# John went to school because he had an exam. However, he was late.
#
# ===== CO-REFERENCE RESOLUTION =====
# John --> Noun/Noun Phrase
# school --> Noun/Noun Phrase
# he --> refers to school
# exam --> Noun/Noun Phrase
# he --> refers to exam
#
# ===== DISCOURSE RELATIONS =====
# because --> Cause
# however --> Contrast
